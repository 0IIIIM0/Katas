# %%
planets = []
new_planet = ''

while new_planet != "done":
    new_planet = input ("Planeta : ")
    planets.append(new_planet)
    print(planets)



for planet in planets:
    print (planet)
# Out:
# ['jorge']
# ['jorge', 'verga larga']
# ['jorge', 'verga larga', 'done']
# jorge
# verga larga
# done
